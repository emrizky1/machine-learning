# %% [markdown]
# <a href="https://colab.research.google.com/github/emrizky1/machine-learning/blob/main/JS02/JS02_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

dpath = 'wbc.csv'
df = pd.read_csv(dpath)
df = df.drop('Unnamed: 32', axis=1)
df.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
le = LabelEncoder()
df['diagnosis'] = le.fit_transform(df['diagnosis'])

# %%
num_cols = df.select_dtypes(include=["float64", "int64"]).columns
num_cols = num_cols.drop(["diagnosis", "id"])

# %%
std = StandardScaler()
df[num_cols] = std.fit_transform(df[num_cols])

# %%
df.head()
# Out:
#          id  diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302          1  ...        2.750622                 1.937015
# 1    842517          1  ...       -0.243890                 0.281190
# 2  84300903          1  ...        1.152255                 0.201391
# 3  84348301          1  ...        6.046041                 4.935010
# 4  84358402          1  ...       -0.868353                -0.397100
#
# [5 rows x 32 columns]
